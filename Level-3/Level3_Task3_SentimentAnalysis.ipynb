# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Load Sentiment dataset
df = pd.read_csv(r"C:\Users\Dell\Desktop\DAPython\Codveda-Internship\datasets\3) Sentiment dataset.csv")

print("✅ Sentiment dataset loaded!")
print("Shape:", df.shape)

# Function to get sentiment
def get_sentiment(text):
    analysis = TextBlob(str(text))
    polarity = analysis.sentiment.polarity
    if polarity > 0.1:
        return "Positive"
    elif polarity < -0.1:
        return "Negative"
    else:
        return "Neutral"

df['Predicted_Sentiment'] = df['Text'].apply(get_sentiment)

print("\nPredicted Sentiment Distribution:")
print(df['Predicted_Sentiment'].value_counts())

# Plot 1: Sentiment Count
plt.figure(figsize=(8,5))
sns.countplot(x='Predicted_Sentiment', data=df, palette='viridis')
plt.title('Predicted Sentiment Distribution')
plt.ylabel('Count')
plt.savefig(r"C:\Users\Dell\Desktop\DAPython\Codveda-Internship\Level-3\sentiment_distribution.png")
plt.show()

# Plot 2: Word Cloud
all_text = ' '.join(df['Text'].astype(str))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

plt.figure(figsize=(10,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Sentiment Dataset')
plt.savefig(r"C:\Users\Dell\Desktop\DAPython\Codveda-Internship\Level-3\sentiment_wordcloud.png")
plt.show()

print("\n🎉 Sentiment Analysis Completed! All files saved in Level-3 folder.")
# Out:
# ✅ Sentiment dataset loaded!
# Shape: (732, 15)
#
# Predicted Sentiment Distribution:
# Predicted_Sentiment
# Neutral     394
# Positive    240
# Negative     98
# Name: count, dtype: int64
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7868\784396890.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Predicted_Sentiment', data=df, palette='viridis')
# 🎉 Sentiment Analysis Completed! All files saved in Level-3 folder.
